# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\SMfaultV.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]
data1 = data1[:, 1]  # Only use the 2nd column (0-indexed)
data1 = data1 / 2521 # Normalize by 2521
time1 = np.arange(len(data1)) # Create time array

# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\GFMfaultV.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2[:, 1]  # Only use the 2nd column (0-indexed)
data2 = data2 / 2401.78 # Normalize by 2401.78
time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(time1, data1, label='SM', linewidth=3)
ax.plot(time2, data2, label='GFM', linestyle='--', linewidth=3)

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (p.u.)', fontdict=font)

# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')

# Set x-limits
ax.set_xlim([800000, max(time1)])
ax.get_xaxis().get_major_formatter().set_scientific(False)
# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))


# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
# Save the figure
plt.savefig('GFM_F.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\SMfaultF.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]
#data1 = data1[:, 1]  # Only use the 2nd column (0-indexed)
data1 = data1 / 60 # Normalize by 2521
time1 = np.arange(len(data1)) # Create time array

# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\GFMfaultf.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2 / 60 # Normalize by 2521


time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(time1, data1, label='SM', linewidth=3)
ax.plot(time2, data2, label='GFM', linestyle='--', linewidth=3)

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

ax.set_ylim([0.2, 1.2])
# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')

# Set x-limits
ax.set_xlim([800000, max(time1)])
ax.get_xaxis().get_major_formatter().set_scientific(False)
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))


# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
# Save the figure
plt.savefig('GFM_F_W_F.pdf', format='pdf') 
plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\SMislanding10.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

# Take the average of the values in columns 1, 2, and 3
avg_data = np.mean(data1[:, 1:4], axis=1)

# Normalize the averaged data
normalized_avg_data = avg_data / 2521

# Create time array for plotting
time1 = np.arange(len(normalized_avg_data))


# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\GFMislanding10.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2[:, 1]  # Only use the 2nd column (0-indexed)
data2 = data2 / 2401.78 # Normalize by 2401.78
time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))




ax.plot(time1, normalized_avg_data, label='SM', linewidth=3)

ax.plot(time2, data2, label='GFM', linestyle='--', linewidth=3)

# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Islanding')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([800000, max(time1)])

# Set x-limits
#ax.set_ylim([0.8,1.6])


ax.get_xaxis().get_major_formatter().set_scientific(False)
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')


# Save the figure
plt.savefig('GFM_IL.pdf', format='pdf')
plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\SMislandingF.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]
time1 = np.arange(len(data1)) # Create time array

# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\GFMislandingF.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]

data2 = data2 / 60
time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(time1, data1, label='SM', linewidth=3)
ax.plot(time2, data2, label='GFM', linestyle='--', linewidth=3)

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([800000, max(time1)])
# Set y-limits
ax.set_ylim([0.2, 1.1])

# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Islanding')

ax.get_xaxis().get_major_formatter().set_scientific(False)
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')


# Save the figure
plt.savefig('GFM_IL_F.pdf', format='pdf')


plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\SMcascadedV.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

# Take the average of the values in columns 1, 2, and 3
avg_data = np.mean(data1[:, 1:4], axis=1)

# Normalize the averaged data
normalized_avg_data = avg_data / 2521

# Create time array for plotting
time1 = np.arange(len(normalized_avg_data))


# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\GFMcascadeV.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2[:, 2]  # Only use the 2nd column (0-indexed)
data2 = data2 / 2401.78 # Normalize by 2401.78
time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, normalized_avg_data, label='SM', linewidth=3)
ax.plot(time2, data2, label='GFM', linestyle='--', linewidth=3)

# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')
# Add a vertical line to the plot
ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([800000, max(time1)])

ax.set_ylim([0, 1.3])

ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
# Save the figure
plt.savefig('GFM_FIL.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\W_SM_FIL.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1)) # Create time array

# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\GFMcascadeF.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]

data2 = data2 / 60# Normalize by 2401.78
time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1, label='SM', linewidth=3)
ax.plot(time2, data2, label='GFM', linestyle='--', linewidth=3)

# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')

ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')


ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([800000, max(time1)])

ax.set_ylim([0.2, 1.2])



ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
    
# Save the figure
plt.savefig('GFM_FIL_F.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1)) # Create time array



# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1, label='SM', linewidth=3)

# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')

ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')


ax.grid(True)
ax.set_xlabel('Time (µs)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([900000, max(time1)])



ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}e6'.format(x*1e-6)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
    
# Save the figure
plt.savefig('GFM_FIL_F.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1971798093.py:64: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1971798093.py:64: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1, label='SM', linewidth=3)

# Add vertical lines to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')
ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')

ax.grid(True)
ax.set_xlabel('Time (µs)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits for zooming
ax.set_xlim([900000, 1100000])  # Update x-limits for zoom

ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}e6'.format(x * 1e-6)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

# Save the figure
plt.savefig('GFM_FIL_F.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1566349275.py:57: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1566349275.py:57: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1[:, 0], label='Phase A', linewidth=3)  # Change label to 'Phase A'
ax.plot(time1, data1[:, 1], label='Phase B', linewidth=3)  # Change label to 'Phase B'
ax.plot(time1, data1[:, 2], label='Phase C', linewidth=3)  # Change label to 'Phase C'

# Add vertical lines to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')
ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')

ax.grid(True)
ax.set_xlabel('Time (µs)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits for higher zoom
ax.set_xlim([950000, 1000000])  # Update x-limits for higher zoom

ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}e6'.format(x * 1e-6)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

# Save the figure
plt.savefig('GFM_FIL_F.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1086419697.py:59: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1086419697.py:59: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1[:, 0], label='Phase A', linewidth=3)  # Change label to 'Phase A'
ax.plot(time1, data1[:, 1], label='Phase B', linewidth=3)  # Change label to 'Phase B'
ax.plot(time1, data1[:, 2], label='Phase C', linewidth=3)  # Change label to 'Phase C'

# Add vertical lines to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')
ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')

ax.grid(True)
ax.set_xlabel('Time (µs)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits for higher zoom
ax.set_xlim([1000000, 1100000])  # Update x-limits for higher zoom

ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}e6'.format(x * 1e-6)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

# Save the figure
plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1321195359.py:59: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/1321195359.py:59: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Find the minimum and maximum values of the data
y_min = np.min(data1)
y_max = np.max(data1)

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1[:, 0], label='Phase A', linewidth=3)
ax.plot(time1, data1[:, 1], label='Phase B', linewidth=3)
ax.plot(time1, data1[:, 2], label='Phase C', linewidth=3)

# Shade the region between 1010000 and 1020000
ax.fill_between(time1, y_min, y_max, where=(time1 >= 1.01e6) & (time1 <= 1.02e6), facecolor='red', alpha=0.2)

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits for higher zoom
ax.set_xlim([1e6, 1.1e6])

ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
    
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x * 1e-6)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

# Save the figure
plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/3967594565.py:63: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/3967594565.py:63: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker
import matplotlib.patches as mpatches

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Find the minimum and maximum values of the data
y_min = np.min(data1)
y_max = np.max(data1)

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1[:, 0], label='Phase A', linewidth=3)
ax.plot(time1, data1[:, 1], label='Phase B', linewidth=3)
ax.plot(time1, data1[:, 2], label='Phase C', linewidth=3)

# Shade vertically from the start to the end of the plot between 1.01e6 and 1.02e6
ax.fill_between(time1, y_min, y_max, where=(time1 >= 1.01e6) & (time1 <= 1.02e6), facecolor='red', alpha=0.2)

# Create custom legend entries
red_patch = mpatches.Patch(color='red', alpha=0.2, label='Short Circuit')

# Gather all legend handles and labels
handles, labels = ax.get_legend_handles_labels()
handles.append(red_patch)

# Set the legend with the custom handle in the upper right corner
legend = ax.legend(handles=handles, fontsize=24, loc='upper right')

# Adjust font settings for the legend
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Frequency (p.u.)', fontdict=font)

# Set x-limits for higher zoom
ax.set_xlim([1e6, 1.1e6])

ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
    
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x * 1e-6)))

# Save the figure
plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker
import matplotlib.patches as mpatches
from matplotlib.ticker import MultipleLocator

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1[:, 0], label='Phase A', linewidth=3)
ax.plot(time1, data1[:, 1], label='Phase B', linewidth=3)
ax.plot(time1, data1[:, 2], label='Phase C', linewidth=3)

# Shade vertically from -4000 to +4000 between 1.01e6 and 1.02e6
ax.fill_between(time1, -4000, 4000, where=(time1 >= 1.01e6) & (time1 <= 1.02e6), facecolor='red', alpha=0.2)

# Create custom legend entries
red_patch = mpatches.Patch(color='red', alpha=0.2, label='Short Circuit')

# Gather all legend handles and labels
handles, labels = ax.get_legend_handles_labels()
handles.append(red_patch)

# Set the legend with the custom handle in the upper right corner
legend = ax.legend(handles=handles, fontsize=24, loc='upper right')

# Adjust font settings for the legend
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (v)', fontdict=font)

# Set x-limits for higher zoom
ax.set_xlim([1e6, 1.1e6])

# Set the major ticks on the x-axis to appear at 0.01 intervals
ax.xaxis.set_major_locator(MultipleLocator(0.01e6))

# Adjust the formatter for x-axis
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:.1f}'.format(x * 1e-5)))

# Save the figure
plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker
import matplotlib.patches as mpatches
from matplotlib.ticker import MultipleLocator

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16, labelweight='bold')  # Here's the change
plt.rc('font', family='Times New Roman', weight='bold')  # And here

ax.plot(time1, data1[:, 0], label='Phase A', linewidth=3)
ax.plot(time1, data1[:, 1], label='Phase B', linewidth=3)
ax.plot(time1, data1[:, 2], label='Phase C', linewidth=3)

# Shade vertically from -4000 to +4000 between 1.01e6 and 1.02e6
ax.fill_between(time1, -4000, 4000, where=(time1 >= 1.01e6) & (time1 <= 1.02e6), facecolor='red', alpha=0.2)

# Create custom legend entries
red_patch = mpatches.Patch(color='red', alpha=0.2, label='Short Circuit')

# Gather all legend handles and labels
handles, labels = ax.get_legend_handles_labels()
handles.append(red_patch)

# Set the legend with the custom handle in the upper right corner
legend = ax.legend(handles=handles, fontsize=24, loc='upper right')

# Adjust font settings for the legend
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (v)', fontdict=font)

# Set x-limits for higher zoom
ax.set_xlim([1e6, 1.1e6])

# Set the major ticks on the x-axis to appear at 0.01 intervals
ax.xaxis.set_major_locator(MultipleLocator(0.01e6))

# Adjust the formatter for x-axis
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:.1f}'.format(x * 1e-5)))

# Save the figure
plt.savefig('GFM_FIL_F_phasor.pdf', format='pdf')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11368/250132137.py in <module>
#      20
#      21 # Adjust the font size and family of the ticks
# ---> 22 ax.tick_params(axis='both', which='major', labelsize=16, labelweight='bold')  # Here's the change
#      23 plt.rc('font', family='Times New Roman', weight='bold')  # And here
#      24
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in tick_params(self, axis, **kwargs)
#    3255             xkw.pop('labelleft', None)
#    3256             xkw.pop('labelright', None)
# -> 3257             self.xaxis.set_tick_params(**xkw)
#    3258         if axis in ['y', 'both']:
#    3259             ykw = dict(kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     839         """
# ...

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1)) # Create time array



# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1, label='SM', linewidth=3)

# Add a vertical line to the plot
#ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')

ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')


ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (v)', fontdict=font)

# Set x-limits
ax.set_xlim([900000, max(time1)])



ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-6)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
    
# Save the figure
plt.savefig('GFM_FIL_F.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/149170119.py:64: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/149170119.py:64: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F.pdf', format='pdf')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\Vphasor.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', **font)

ax.plot(time1, data1[:, 0], label='Phase A', linewidth=3)
ax.plot(time1, data1[:, 1], label='Phase B', linewidth=3)
ax.plot(time1, data1[:, 2], label='Phase C', linewidth=3)

# Add a vertical line to the plot
ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (v)', fontdict=font)

# Set x-limits to focus on the interval from 1.1 seconds to 1.3 seconds
ax.set_xlim([1.19e6, 1.22e6])

# Adjust x-axis formatting
ax.get_xaxis().get_major_formatter().set_scientific(False)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.2f}'.format(x*1e-5)))

# Set font style for x and y ticks
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
    
# Save the figure
plt.savefig('GFM_FIL_F_islanding.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/2806844058.py:51: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F_islanding.pdf', format='pdf')
# C:\Users\aes21009\AppData\Local\Temp/ipykernel_11368/2806844058.py:51: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('GFM_FIL_F_islanding.pdf', format='pdf')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\VCLPURMS.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

time1 = np.arange(len(data1)) # Create time array



# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Adjust the font size and family of the ticks
ax.tick_params(axis='both', which='major', labelsize=16)
plt.rc('font', family='Times New Roman')

ax.plot(time1, data1, label='SM', linewidth=3)

# Add a vertical line to the plot
#ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')

#ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')


ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (v)', fontdict=font)

# Set x-limits
#ax.set_xlim([900000, max(time1)])



ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-6)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
    
# Save the figure
plt.savefig('GFM_CLPU.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the first plot
#mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\VRMS_GFM_F.mat')
#varname = list(mat.keys())[3]  # Skipping the meta-information keys
#data1 = mat[varname]
#data1 = data1[:, 1]  # Only use the 2nd column (0-indexed)
#data1 = data1 / 2521 # Normalize by 2521
#time1 = np.arange(len(data1)) # Create time array

# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\VCLPURMS.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2[:, 0]  # Only use the 2nd column (0-indexed)
data2 = data2 / 2401.78 # Normalize by 2401.78
time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

#ax.plot(time1, data1, label='SM', linewidth=3)
ax.plot(time2, data2, label='GFM', linewidth=3)

ax.grid(True)
ax.set_xlabel('Time (µs)', fontdict=font)
ax.set_ylabel('Voltage (p.u.)', fontdict=font)

# Add a vertical line to the plot
#ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')

# Set x-limits
ax.set_xlim([1, max(time2)])
ax.get_xaxis().get_major_formatter().set_scientific(False)
# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))


# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')
    
# Save the figure
plt.savefig('GFM_CLPU.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\VCLPURMS.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2[:, 0]  # Only use the 2nd column (0-indexed)
data2 = data2 / 2401.78  # Normalize by 2401.78
time2 = np.arange(len(data2))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(time2, data2, label='GFM', linewidth=3)

# Add shaded region from 5 to 6
ax.axvspan(500000, 600000, color='gray', alpha=0.5)

# Add a vertical line at 6 with the label 'cold load pick up'
ax.axvline(600000, color='red', linestyle='--', linewidth=3, label='CLPU')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([1, max(time2)])
ax.get_xaxis().get_major_formatter().set_scientific(False)
# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x * 1e-5)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

# Save the figure
plt.savefig('GFM_CLPU.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker
import matplotlib.patches as mpatches

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\VCLPURMS.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2[:, 0]  # Only use the 2nd column (0-indexed)
data2 = data2 / 2401.78  # Normalize by 2401.78
time2 = np.arange(len(data2))  # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(time2, data2, label='GFM', linewidth=3)

# Add shaded region from 5 to 6
outage_patch = mpatches.Patch(color='gray', alpha=0.5, label='Outage')
ax.axvspan(500000, 600000, color='gray', alpha=0.5)

# Add a vertical line at 6 with the label 'cold load pick up'
ax.axvline(600000, color='red', linestyle='--', linewidth=3, label='CLPU')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([1, max(time2)])
ax.get_xaxis().get_major_formatter().set_scientific(False)

# Set font style for x and y ticks
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x * 1e-5)))

# Set font size for legend with the added custom legend entry
legend = ax.legend(handles=[outage_patch] + ax.lines, loc='lower right')
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')

# Save the figure
plt.savefig('GFM_CLPU.pdf', format='pdf')

plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the font properties
font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 24}

# Load the .mat file
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\SMcascadedV.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data1 = mat[varname]

# Take the average of the values in columns 1, 2, and 3
avg_data = np.mean(data1[:, 1:4], axis=1)

# Normalize the averaged data
normalized_avg_data = avg_data / 2521

# Create time array for plotting
time1 = np.arange(len(normalized_avg_data))


# Load the .mat file for the second plot
mat = scipy.io.loadmat(r'C:\Users\aes21009\Downloads\GFMcascadeV.mat')
varname = list(mat.keys())[3]  # Skipping the meta-information keys
data2 = mat[varname]
data2 = data2[:, 1]  # Only use the 2nd column (0-indexed)
data2 = data2 / 2401.78 # Normalize by 2401.78
time2 = np.arange(len(data2)) # Create time array

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))




ax.plot(time1, normalized_avg_data, label='SM', linewidth=3)

ax.plot(time2, data2, label='GFM', linestyle='--', linewidth=3)

# Add a vertical line to the plot
ax.axvline(1.01e6, color='red', linestyle=':', linewidth=3, label='Fault')
# Add a vertical line to the plot
ax.axvline(1.2e6, color='purple', linestyle=':', linewidth=3, label='Islanding')

ax.grid(True)
ax.set_xlabel('Time (s)', fontdict=font)
ax.set_ylabel('Voltage (p.u.)', fontdict=font)

# Set x-limits
ax.set_xlim([800000, max(time1)])

# Set x-limits
#ax.set_ylim([0.8,1.6])


ax.get_xaxis().get_major_formatter().set_scientific(False)
for label in ax.get_xticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
for label in ax.get_yticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontweight('bold')
    label.set_fontsize(24)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:0.1f}'.format(x*1e-5)))

# Set font size for legend
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(24)
    text.set_fontname('Times New Roman')
    text.set_fontweight('bold')


# Save the figure
plt.savefig('GFM_IL_1.pdf', format='pdf')
plt.show()
